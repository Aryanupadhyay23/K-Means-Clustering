# %% [markdown]
# <a href="https://colab.research.google.com/github/Aryanupadhyay23/K-Means-Clustering/blob/main/k-means.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

# Parameters
n_samples = 300
n_features = 2
centers = 4

# Generate data
X, y = make_blobs(n_samples=n_samples, n_features=n_features, centers=centers, cluster_std=3, random_state=42)

# Visualize the data
plt.scatter(X[:, 0], X[:, 1], s=50, cmap='viridis')
plt.title("Generated Dataset for K-Means Clustering")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()
# Out:
# /tmp/ipython-input-179792226.py:14: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X[:, 0], X[:, 1], s=50, cmap='viridis')

# %%
from sklearn.cluster import KMeans

wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_init = 10, n_clusters = i)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

# %%
plt.plot(range(1,11),wcss)

# %%
from sklearn.metrics import silhouette_score
sil = []
for i in range(2, 11):
    kmeans = KMeans(n_clusters=i)
    cluster_labels = kmeans.fit_predict(X)
    silhouette_avg = silhouette_score(X, cluster_labels)
    sil.append(silhouette_avg)

# %%
plt.plot(range(2,11),sil)

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_init = 10, n_clusters = 4, verbose=100)
kmeans.fit(X)
# Out:
# Initialization complete
# Iteration 0, inertia 8156.851683422836.
# Iteration 1, inertia 4604.897307725037.
# Iteration 2, inertia 4518.688361835802.
# Iteration 3, inertia 4491.1530750426755.
# Iteration 4, inertia 4478.256961050586.
# Iteration 5, inertia 4475.918395021896.
# Converged at iteration 5: strict convergence.
# Initialization complete
# Iteration 0, inertia 5285.82699892269.
# Iteration 1, inertia 4503.103782331643.
# Iteration 2, inertia 4479.174755841133.
# Iteration 3, inertia 4475.918395021896.
# Converged at iteration 3: strict convergence.
# Initialization complete
# Iteration 0, inertia 11155.092890356125.
# Iteration 1, inertia 6230.665044490919.
# Iteration 2, inertia 4675.897379967198.
# Iteration 3, inertia 4576.728981143979.
# Iteration 4, inertia 4500.708459056743.
# Iteration 5, inertia 4479.174755841133.
# Iteration 6, inertia 4475.918395021896.
# Converged at iteration 6: strict convergence.
# Initialization complete
# Iteration 0, inertia 5758.992215145704.
# Iteration 1, inertia 4633.008312965531.
# Iteration 2, inertia 4541.247886028638.
# Iteration 3, inertia 4489.527792818062.
# Iteration 4, inertia 4479.174755841133.
# Iteration 5, inertia 4475.918395021896.
# Converged at iteration 5: strict convergence.
# Initialization complete
# Iteration 0, inertia 6085.282762763238.
# Iteration 1, inertia 4720.026125197365.
# Iteration 2, inertia 4568.78481135846.
# Iteration 3, inertia 4521.1207384986965.
# Iteration 4, inertia 4492.562586381866.
# Iteration 5, inertia 4477.333098866025.
# Iteration 6, inertia 4475.918395021896.
# Converged at iteration 6: strict convergence.
# Initialization complete
# Iteration 0, inertia 6540.272399864082.
# Iteration 1, inertia 4701.235645411158.
# Iteration 2, inertia 4589.044268494807.
# Iteration 3, inertia 4529.190968695926.
# Iteration 4, inertia 4511.5558358283515.
# Iteration 5, inertia 4502.292265773572.
# Iteration 6, inertia 4489.425558875599.
# Iteration 7, inertia 4480.471438687805.
# Iteration 8, inertia 4475.918395021896.
# Converged at iteration 8: strict convergence.
# Initialization complete
# Iteration 0, inertia 7888.4936074185.
# Iteration 1, inertia 5186.560781413953.
# Iteration 2, inertia 4692.539410354652.
# Iteration 3, inertia 4566.189162596771.
# Iteration 4, inertia 4505.197233867234.
# Iteration 5, inertia 4482.846697455921.
# Iteration 6, inertia 4475.918395021896.
# Converged at iteration 6: strict convergence.
# Initialization complete
# Iteration 0, inertia 6507.625612435692.
# Iteration 1, inertia 4606.175046811753.
# Iteration 2, inertia 4528.259677911685.
# Iteration 3, inertia 4512.795011773233.
# Iteration 4, inertia 4502.292265773572.
# Iteration 5, inertia 4489.425558875599.
# Iteration 6, inertia 4480.471438687805.
# Iteration 7, inertia 4475.918395021896.
# Converged at iteration 7: strict convergence.
# Initialization complete
# Iteration 0, inertia 7368.569262430325.
# Iteration 1, inertia 4556.229135379022.
# Iteration 2, inertia 4482.795921467387.
# Iteration 3, inertia 4475.918395021896.
# Converged at iteration 3: strict convergence.
# Initialization complete
# Iteration 0, inertia 6653.037435141976.
# Iteration 1, inertia 5250.43993128114.
# Iteration 2, inertia 4815.052557370355.
# Iteration 3, inertia 4594.301676143735.
# Iteration 4, inertia 4504.303780419534.
# Iteration 5, inertia 4477.306632870448.
# Iteration 6, inertia 4475.918395021896.
# Converged at iteration 6: strict convergence.
# KMeans(n_clusters=4, n_init=10, verbose=100)

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from sklearn.datasets import make_blobs

from sklearn.metrics import silhouette_samples, silhouette_score
import numpy as np


# Setting up the subplot grid
fig = plt.figure(figsize=(15, 20))
gs = gridspec.GridSpec(4, 2, width_ratios=[1, 2])

# Creating silhouette and scatter plots for different values of k (2, 3, 4, 5)
for i, k in enumerate([2, 3, 4, 5]):
    # Clustering with k-means
    kmeans = KMeans(n_init=10, n_clusters=k, random_state=10)
    cluster_labels = kmeans.fit_predict(X)

    # Silhouette values
    silhouette_vals = silhouette_samples(X, cluster_labels)
    avg_score = silhouette_score(X, cluster_labels)

    # Silhouette plot
    ax1 = plt.subplot(gs[i, 0])
    y_lower, y_upper = 0, 0
    yticks = []
    for j, cluster in enumerate(np.unique(cluster_labels)):
        cluster_silhouette_vals = silhouette_vals[cluster_labels == cluster]
        cluster_silhouette_vals.sort()
        y_upper += len(cluster_silhouette_vals)
        ax1.barh(range(y_lower, y_upper), cluster_silhouette_vals, edgecolor='none', height=1)
        yticks.append((y_lower + y_upper) / 2)
        y_lower += len(cluster_silhouette_vals)
    ax1.axvline(avg_score, color="red", linestyle="--")
    ax1.set_yticks(yticks)
    ax1.set_yticklabels([f'Cluster {x}' for x in np.unique(cluster_labels)])
    ax1.set_ylabel('Cluster')
    ax1.set_xlabel('Silhouette Coefficient')
    ax1.set_title(f'Silhouette Plot for k={k}')

    # Scatter plot
    ax2 = plt.subplot(gs[i, 1])
    for j in np.unique(cluster_labels):
        ax2.scatter(X[cluster_labels == j, 0], X[cluster_labels == j, 1], label=f'Cluster {j}')
    ax2.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=100, c='black', marker='X', label='Centroids')
    ax2.set_title(f'Cluster Visualization for k={k}')
    ax2.legend()

plt.tight_layout()
plt.show()

# %%
y_kmeans = kmeans.fit_predict(X)

# %%
y_kmeans
# Out:
# array([1, 1, 2, 3, 1, 3, 0, 3, 4, 2, 4, 0, 2, 1, 1, 4, 1, 2, 4, 4, 0, 4,
#        3, 1, 4, 4, 1, 3, 3, 2, 1, 2, 1, 0, 1, 4, 1, 3, 1, 3, 0, 4, 1, 3,
#        2, 4, 1, 2, 1, 0, 3, 1, 3, 2, 3, 4, 1, 0, 0, 4, 1, 0, 0, 4, 3, 3,
#        3, 3, 3, 4, 3, 3, 1, 0, 2, 1, 3, 3, 4, 3, 4, 4, 1, 4, 3, 1, 4, 0,
#        0, 2, 1, 4, 1, 4, 4, 1, 3, 4, 1, 4, 2, 0, 0, 2, 4, 2, 2, 4, 3, 1,
#        0, 4, 4, 2, 4, 0, 1, 3, 1, 3, 3, 3, 2, 1, 3, 1, 1, 4, 1, 3, 0, 1,
#        2, 1, 1, 0, 0, 1, 4, 3, 4, 0, 2, 4, 2, 2, 0, 0, 3, 4, 1, 4, 0, 3,
#        4, 2, 3, 1, 1, 2, 1, 1, 3, 1, 0, 1, 3, 4, 4, 2, 4, 4, 3, 2, 2, 3,
#        3, 4, 0, 3, 1, 4, 1, 0, 0, 1, 3, 2, 3, 2, 3, 3, 3, 1, 2, 3, 3, 0,
#        2, 1, 4, 4, 3, 2, 4, 3, 3, 1, 3, 4, 4, 3, 3, 2, 1, 3, 4, 1, 1, 1,
#        1, 3, 1, 3, 2, 2, 1, 4, 2, 0, 0, 4, 4, 3, 0, 3, 1, 0, 4, 1, 4, 3,
#        3, 0, 4, 3, 3, 3, 1, 3, 1, 3, 1, 0, 3, 1, 2, 4, 1, 4, 2, 4, 1, 1,
#        3, 2, 3, 0, 0, 4, 4, 3, 2, 0, 1, 1, 3, 1, 4, 2, 2, 0, 0, 3, 1, 0,
#        3, 0, 2, 3, 4, 3, 0, 4, 1, 4, 2, 1, 1, 4], dtype=int32)

# %%
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s = 60, c = 'red', label = 'Cluster1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s = 60, c = 'blue', label = 'Cluster2')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s = 60, c = 'green', label = 'Cluster3')
plt.scatter(X[y_kmeans == 3, 0], X[y_kmeans == 3, 1], s = 60, c = 'yellow', label = 'Cluster4')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 100, c = 'black', label = 'Centroids')

plt.legend()

plt.show()
